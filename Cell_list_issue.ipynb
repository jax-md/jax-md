             [-2.07671285e+00,  5.57216311e+00, -6.36687660e+00],
             [-1.82437992e+00,  5.40315628e+00, -6.35367584e+00],
             [-1.78955126e+00,  5.32309914e+00, -6.09710789e+00],
             [-3.39747047e+00,  5.91309357e+00, -6.09378147e+00],
             [-7.98125207e-01,  8.67413998e-01,  2.93304443e-01],
             [-3.08678031e-01,  4.01735842e-01,  2.40114331e-02],
             [-3.41866136e-01,  1.15495872e+00, -5.60066700e-02],
             [-5.17898369e+00, -2.53559995e+00, -2.75050974e+00],
             [-7.18106747e+00, -1.51256120e+00, -2.45449018e+00],
             [-7.35948753e+00, -7.38258541e-01, -2.03656197e+00],
             [-4.95314169e+00, -5.65342546e-01, -2.25823975e+00],
             [-6.05947161e+00,  4.00974214e-01, -3.05927467e+00],
             [-4.87638187e+00, -2.91807204e-03, -4.10165453e+00],
             [-6.44678020e+00, -1.34199369e+00,  3.75325489e+00],
             [-5.83700037e+00, -1.73771441e+00,  3.77577686e+00],
             [-5.95989084e+00, -1.07372594e+00,  3.43100691e+00],
             [-9.47790813e+00, -5.87469959e+00,  2.41070414e+00],
             [-1.09105272e+01, -5.25399160e+00,  2.36160707e+00],
             [-1.17365122e+01, -5.00117683e+00,  1.60019982e+00],
             [-9.71687508e+00, -4.57477999e+00,  1.81762087e+00],
             [-1.07625618e+01, -4.58950233e+00,  7.71928191e-01],
             [-9.35400391e+00, -5.17472649e+00,  7.20306277e-01]])

box_size_multiplier=1.25
dr_threshold=1.0
cutoff=7.0
d = jnp.linalg.norm(xyz[87]-xyz[91])
print(f'Distance between pair 87,91 is {d:.2f} Angstrom. Cutoff is {cutoff} Angstrom')

box_size = (xyz.max(0) - xyz.min(0))*box_size_multiplier
displacement_fn_periodic, shift_fn_periodic = space.periodic(box_size, wrapped=False)

def check_for_match(disable_cell_list=False):
    neighbor_fn = partition.neighbor_list(
        displacement_fn_periodic, 
        box_size, 
        cutoff, 
        dr_threshold, 
        format=partition.NeighborListFormat.OrderedSparse, 
        disable_cell_list=disable_cell_list
    )
    nbrs = neighbor_fn.allocate(xyz)
    nbrs_subset = nbrs.idx[...,jnp.any(nbrs.idx==91, axis=0)]
    nbr_present = jnp.any(nbrs_subset==87)

    did_use_cell_list = nbrs.cell_list_capacity!=None

    print(f'Did use cell list: {did_use_cell_list} -> Does pair (87,91) exist in neighborlist?: {nbr_present}')

check_for_match()
check_for_match(True)
# Out:
#      |████████████████████████████████| 287 kB 15.9 MB/s
#      |████████████████████████████████| 75 kB 3.8 MB/s
# ...
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Distance between pair 87,91 is 6.07 Angstrom. Cutoff is 7.0 Angstrom
# /usr/local/lib/python3.7/dist-packages/jax/_src/numpy/lax_numpy.py:3552: UserWarning: Explicitly requested dtype <class 'jax._src.numpy.lax_numpy.int64'> requested in array is not available, and will be truncated to dtype int32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/google/jax#current-gotchas for more.
#   lax._check_user_dtype_supported(dtype, "array")
# Did use cell list: True -> Does pair (87,91) exist in neighborlist?: False
# Did use cell list: False -> Does pair (87,91) exist in neighborlist?: True

# %% [markdown]
# With the linked cell list, one (exactly one) pair is missing. That hints towards something like an indexing error < where it should be <=.
