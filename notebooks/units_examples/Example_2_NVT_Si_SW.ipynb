# %%
#@title Imports & Utils
# !pip install -q git+https://www.github.com/google/jax-md

import jax.numpy as jnp
import numpy as onp
from jax import debug
from jax import jit
from jax import grad
from jax import random
from jax import lax
from jax.config import config

config.update('jax_enable_x64', True)
from jax_md import simulate
from jax_md import space
from jax_md import energy
from jax_md import elasticity
from jax_md import quantity
from jax_md import dataclasses
from jax_md.util import f64

# Other libraries
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd 

# LAMMPS data
# !wget https://raw.githubusercontent.com/abhijeetgangan/Silicon-data/main/Si-SW-MD/NVT-300K/lammps_nvt.dat
# !wget https://raw.githubusercontent.com/abhijeetgangan/Silicon-data/main/Si-SW-MD/NVE-300K/step_1.traj
data_lammps = pd.read_csv("lammps_nvt.dat", delim_whitespace="  ", header=None)
data_lammps = data_lammps.dropna(axis=1)
data_lammps.columns = ['Time','T','P','V','E','H']
t_l, T, P, V, E, H = data_lammps['Time'], data_lammps['T'], data_lammps['P'], data_lammps['V'], data_lammps['E'], data_lammps['H']
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.4/197.4 KB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 KB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 KB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 KB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 KB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 88.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.1/238.1 KB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 KB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 5.4 MB/s eta 0:00:00
#   Building wheel for jax-md (setup.py) ... done
#   Building wheel for ml_collections (setup.py) ... done
# --2023-01-11 05:21:23--  https://raw.githubusercontent.com/abhijeetgangan/Silicon-data/main/Si-SW-MD/NVT-300K/lammps_nvt.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39579 (39K) [text/plain]
# Saving to: ‘lammps_nvt.dat’
#
# lammps_nvt.dat      100%[===================>]  38.65K  --.-KB/s    in 0s
#
# 2023-01-11 05:21:23 (137 MB/s) - ‘lammps_nvt.dat’ saved [39579/39579]
#
# --2023-01-11 05:21:23--  https://raw.githubusercontent.com/abhijeetgangan/Silicon-data/main/Si-SW-MD/NVE-300K/step_1.traj
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64303 (63K) [text/plain]
# Saving to: ‘step_1.traj’
#
# step_1.traj         100%[===================>]  62.80K  --.-KB/s    in 0.001s
#
# 2023-01-11 05:21:23 (48.0 MB/s) - ‘step_1.traj’ saved [64303/64303]

# %% [markdown]
# # Using units in JAX-MD (NVT simulation)
#
# This notebook demonstrates the use of a unit system (metal units) for the simulation of the Silicon crystal containing 512 atoms in the NVT ensemble with the Stillinger-Weber potential. This notebook use lammps velocities and positions as a starting point for the simulation and for comparison.
#
# More about the unit system https://docs.lammps.org/units.html

# %% [markdown]
# ## Load LAMMPS positions and velocities.

# %%
lammps_step_0 = onp.loadtxt('/content/step_1.traj', dtype=f64)

# %%
# Load positions from lammps
positions = jnp.array(lammps_step_0[:,2:5], dtype=f64)
# Load velocities from lammps
velocity = jnp.array(lammps_step_0[:,5:8], dtype=f64)
latvec = jnp.array([[21.724, 0.000000, 0.000000], [0.00000, 21.724, 0.00000],[0.00000, 0.0000, 21.724]])

# %% [markdown]
# ## Units and simulation parameters

# %%
# Import unit system
from jax_md import units

# Metal units
unit = units.metal_unit_system()

# %%
# Simulation parameters
timestep = 1e-3
fs = timestep * unit['time']
ps = unit['time']
dt = fs
write_every = 100
box = latvec
T_init = 300 * unit['temperature']
Mass = 28.0855 * unit['mass']
key = random.PRNGKey(121)
steps = 50000

# %%
# Logger to save data
log = {
'E': jnp.zeros((steps // write_every,)),
'P': jnp.zeros((steps // write_every,)),
'T': jnp.zeros((steps // write_every,)),
'kT': jnp.zeros((steps // write_every,)),
}

# %% [markdown]
# ## Simulation setup

# %%
# Setup the periodic boundary conditions. 
displacement, shift = space.periodic_general(latvec) 
dist_fun = space.metric(displacement) 
neighbor_fn, energy_fn = energy.stillinger_weber_neighbor_list(displacement, latvec, disable_cell_list=True)
energy_fn = jit(energy_fn)

# %%
# Extra capacity to prevent overflow
nbrs = neighbor_fn.allocate(positions, box=box, extra_capacity=2)

# NVT simulation
init_fn, apply_fn = simulate.nvt_nose_hoover(energy_fn, shift, dt=dt, kT=T_init, tau=100 * dt, chain_length=3, chain_steps=1, sy_steps=1)
apply_fn = jit(apply_fn)
state = init_fn(key, positions, box=box, neighbor=nbrs, kT=T_init, mass=Mass)

# Restart from LAMMPS velocities
state = dataclasses.replace(state, momentum = Mass * velocity * unit['velocity'])
# Out:
# /usr/local/lib/python3.8/dist-packages/jax/_src/ops/scatter.py:87: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int64 to dtype=int32. In future JAX releases this will result in an error.
#   warnings.warn("scatter inputs have incompatible types: cannot safely cast "

# %% [markdown]
# ## NVT simulation

# %%
@jit
def step_fn(i, state_nbrs):  
  state, nbrs = state_nbrs
  # Take a simulation step.
  t = i * dt
  state = apply_fn(state, neighbor=nbrs, kT=T_init)
  nbrs = nbrs.update(state.position, neighbor=nbrs)
  return state, nbrs
    
@jit
def outer_sim_fn(j, state_nbrs_log):
  state, nbrs, log = state_nbrs_log

  # Quantities to calculate
  K  = quantity.kinetic_energy(momentum = state.momentum, mass=Mass)
  E  = energy_fn(state.position, box=box, neighbor=nbrs)
  kT = quantity.temperature(momentum = state.momentum, mass=Mass)
  P  = quantity.pressure(energy_fn, state.position, box, K, neighbor=nbrs)

  # Save the quantities
  log['T'] = log['T'].at[j].set(simulate.nvt_nose_hoover_invariant(energy_fn, state, T_init, neighbor=nbrs))
  log['E'] = log['E'].at[j].set(E)
  log['kT'] = log['kT'].at[j].set(kT)
  log['P'] = log['P'].at[j].set(P)

  # Print the quantities
  debug.print('Step = {j} | Total Energy = {T}', j=j*write_every, T=K+E)

  @jit
  def inner_sim_fn(i, state_nbrs):
    return step_fn(i, state_nbrs)
      
  state, nbrs = lax.fori_loop(0, write_every, inner_sim_fn, (state, nbrs))

  return state, nbrs, log

# %%
state_r, nbrs_r, log_r = lax.fori_loop(0, int(steps/write_every), outer_sim_fn, (state, nbrs, log))
# Out:
# /usr/local/lib/python3.8/dist-packages/jax/_src/ops/scatter.py:87: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int64 to dtype=int32. In future JAX releases this will result in an error.
#   warnings.warn("scatter inputs have incompatible types: cannot safely cast "
# Step = 0 | Total Energy = -2200.4826561382047
# Step = 100 | Total Energy = -2198.404431521388
# Step = 200 | Total Energy = -2194.896508716625
# Step = 300 | Total Energy = -2190.6609239508302
# Step = 400 | Total Energy = -2186.1594062376957
# Step = 500 | Total Energy = -2182.0269534285762
# Step = 600 | Total Energy = -2178.6853137851726
# Step = 700 | Total Energy = -2177.767341757199
# Step = 800 | Total Energy = -2179.2815316785486
# Step = 900 | Total Energy = -2181.3974350851595
# Step = 1000 | Total Energy = -2182.5290226217944
# Step = 1100 | Total Energy = -2181.617075050357
# Step = 1200 | Total Energy = -2179.9091386304412
# Step = 1300 | Total Energy = -2178.811215396532
# Step = 1400 | Total Energy = -2179.0849494175386
# Step = 1500 | Total Energy = -2180.6357595247314
# Step = 1600 | Total Energy = -2181.706258608333
# Step = 1700 | Total Energy = -2181.722900661548
# Step = 1800 | Total Energy = -2180.4918165347867
# Step = 1900 | Total Energy = -2179.3964254670395
# Step = 2000 | Total Energy = -2179.0661387369646
# Step = 2100 | Total Energy = -2180.1834303541027
# Step = 2200 | Total Energy = -2181.2379096964382
# Step = 2300 | Total Energy = -2181.675046814199
# Step = 2400 | Total Energy = -2181.0344787506056
# Step = 2500 | Total Energy = -2179.9180966785434
# Step = 2600 | Total Energy = -2179.3238603507534
# Step = 2700 | Total Energy = -2179.8915999722076
# Step = 2800 | Total Energy = -2181.5056113307046
# Step = 2900 | Total Energy = -2181.680520721114
# Step = 3000 | Total Energy = -2180.946847254221
# Step = 3100 | Total Energy = -2180.3902407993533
# Step = 3200 | Total Energy = -2180.2468316713107
# Step = 3300 | Total Energy = -2180.3838472223165
# Step = 3400 | Total Energy = -2180.4428387346106
# Step = 3500 | Total Energy = -2181.14884809508
# Step = 3600 | Total Energy = -2181.8377160650193
# Step = 3700 | Total Energy = -2181.4962220895804
# Step = 3800 | Total Energy = -2179.737100841847
# Step = 3900 | Total Energy = -2179.5103470773856
# Step = 4000 | Total Energy = -2180.0818520548337
# Step = 4100 | Total Energy = -2181.086314107744
# Step = 4200 | Total Energy = -2182.3329816947976
# Step = 4300 | Total Energy = -2182.8541029154076
# Step = 4400 | Total Energy = -2181.535657933705
# Step = 4500 | Total Energy = -2180.0506233707397
# Step = 4600 | Total Energy = -2179.5015256930274
# Step = 4700 | Total Energy = -2179.8500812183943
# Step = 4800 | Total Energy = -2181.2653518987945
# Step = 4900 | Total Energy = -2181.771024522377
# Step = 5000 | Total Energy = -2181.046345958877
# Step = 5100 | Total Energy = -2180.3089887513615
# Step = 5200 | Total Energy = -2180.215083330055
# Step = 5300 | Total Energy = -2180.5484824918753
# Step = 5400 | Total Energy = -2180.5917515817523
# Step = 5500 | Total Energy = -2180.718647649638
# Step = 5600 | Total Energy = -2180.6439340318816
# Step = 5700 | Total Energy = -2180.2510997058744
# Step = 5800 | Total Energy = -2179.4460211524774
# Step = 5900 | Total Energy = -2179.2687421973224
# Step = 6000 | Total Energy = -2180.5885823925787
# Step = 6100 | Total Energy = -2181.661706984724
# Step = 6200 | Total Energy = -2181.457904109004
# Step = 6300 | Total Energy = -2180.3591728329543
# Step = 6400 | Total Energy = -2179.9143719762574
# Step = 6500 | Total Energy = -2179.9872940493133
# Step = 6600 | Total Energy = -2180.516261575324
# Step = 6700 | Total Energy = -2181.137353438759
# Step = 6800 | Total Energy = -2181.964837245194
# Step = 6900 | Total Energy = -2182.466563957243
# Step = 7000 | Total Energy = -2180.883368298311
# Step = 7100 | Total Energy = -2179.8244567567103
# Step = 7200 | Total Energy = -2179.7467968710666
# Step = 7300 | Total Energy = -2180.5364923795655
# Step = 7400 | Total Energy = -2181.8363438942743
# Step = 7500 | Total Energy = -2183.1877685837107
# Step = 7600 | Total Energy = -2182.388768811658
# Step = 7700 | Total Energy = -2180.405739233405
# Step = 7800 | Total Energy = -2179.7187115379375
# Step = 7900 | Total Energy = -2179.712755936367
# Step = 8000 | Total Energy = -2180.7055754954113
# Step = 8100 | Total Energy = -2181.570850780325
# Step = 8200 | Total Energy = -2181.6856144936405
# Step = 8300 | Total Energy = -2179.6390881501875
# Step = 8400 | Total Energy = -2179.163234283476
# Step = 8500 | Total Energy = -2179.90401104881
# Step = 8600 | Total Energy = -2181.1700966437875
# Step = 8700 | Total Energy = -2181.470967431989
# Step = 8800 | Total Energy = -2180.5883604337137
# Step = 8900 | Total Energy = -2178.8409940526235
# Step = 9000 | Total Energy = -2178.9624374247596
# Step = 9100 | Total Energy = -2179.8873668117785
# Step = 9200 | Total Energy = -2180.8055684650544
# Step = 9300 | Total Energy = -2181.2681600924802
# Step = 9400 | Total Energy = -2180.837339306182
# Step = 9500 | Total Energy = -2178.794594823454
# Step = 9600 | Total Energy = -2178.7602069109416
# Step = 9700 | Total Energy = -2179.9197491583946
# Step = 9800 | Total Energy = -2180.7876303599774
# Step = 9900 | Total Energy = -2180.7689543176066
# Step = 10000 | Total Energy = -2180.5312544474523
# Step = 10100 | Total Energy = -2179.3916692192397
# Step = 10200 | Total Energy = -2177.946526952475
# Step = 10300 | Total Energy = -2178.8739780416827
# Step = 10400 | Total Energy = -2180.1596618300723
# Step = 10500 | Total Energy = -2180.5557200709195
# Step = 10600 | Total Energy = -2180.6453208942003
# Step = 10700 | Total Energy = -2180.9040587956147
# Step = 10800 | Total Energy = -2180.5543953268466
# Step = 10900 | Total Energy = -2179.7186436385928
# Step = 11000 | Total Energy = -2179.1054290461793
# Step = 11100 | Total Energy = -2179.775033325203
# Step = 11200 | Total Energy = -2181.2659753504904
# Step = 11300 | Total Energy = -2181.4635046578023
# Step = 11400 | Total Energy = -2180.7129736028824
# Step = 11500 | Total Energy = -2179.7569037801013
# Step = 11600 | Total Energy = -2179.7974375455087
# Step = 11700 | Total Energy = -2180.000492247127
# Step = 11800 | Total Energy = -2180.889376038166
# Step = 11900 | Total Energy = -2181.397568699925
# Step = 12000 | Total Energy = -2181.2442626660263
# Step = 12100 | Total Energy = -2179.7644761341535
# Step = 12200 | Total Energy = -2179.0899924577207
# Step = 12300 | Total Energy = -2179.81987114214
# Step = 12400 | Total Energy = -2181.190371325143
# Step = 12500 | Total Energy = -2181.416984960331
# Step = 12600 | Total Energy = -2180.9137981055383
# Step = 12700 | Total Energy = -2180.619253541083
# Step = 12800 | Total Energy = -2180.085693136454
# Step = 12900 | Total Energy = -2179.9034991145722
# Step = 13000 | Total Energy = -2179.900576592214
# Step = 13100 | Total Energy = -2180.423502602388
# Step = 13200 | Total Energy = -2181.281635804756
# Step = 13300 | Total Energy = -2181.3521353372666
# Step = 13400 | Total Energy = -2180.180432620448
# Step = 13500 | Total Energy = -2178.8493050786346
# Step = 13600 | Total Energy = -2179.3690448461844
# Step = 13700 | Total Energy = -2180.0757569351813
# Step = 13800 | Total Energy = -2180.5371781903814
# Step = 13900 | Total Energy = -2180.557237093123
# Step = 14000 | Total Energy = -2180.437148018912
# Step = 14100 | Total Energy = -2179.831029918384
# Step = 14200 | Total Energy = -2178.850123996063
# Step = 14300 | Total Energy = -2179.4144626928596
# Step = 14400 | Total Energy = -2180.9460720046663
# Step = 14500 | Total Energy = -2181.46004413376
# Step = 14600 | Total Energy = -2180.9372133182683
# Step = 14700 | Total Energy = -2180.14423117097
# Step = 14800 | Total Energy = -2179.755770506782
# Step = 14900 | Total Energy = -2179.945819249165
# Step = 15000 | Total Energy = -2181.828038927475
# Step = 15100 | Total Energy = -2182.1911432620846
# Step = 15200 | Total Energy = -2180.9576295697248
# Step = 15300 | Total Energy = -2179.6980561974497
# Step = 15400 | Total Energy = -2179.7263410839173
# Step = 15500 | Total Energy = -2180.3746688818933
# Step = 15600 | Total Energy = -2182.0935289611566
# Step = 15700 | Total Energy = -2182.166198383949
# Step = 15800 | Total Energy = -2181.3583352733026
# Step = 15900 | Total Energy = -2180.635016432401
# Step = 16000 | Total Energy = -2180.100211488411
# Step = 16100 | Total Energy = -2179.802987199323
# Step = 16200 | Total Energy = -2180.456635406112
# Step = 16300 | Total Energy = -2181.9732411919153
# Step = 16400 | Total Energy = -2181.8556592621326
# Step = 16500 | Total Energy = -2180.489111578582
# Step = 16600 | Total Energy = -2179.6958456872135
# Step = 16700 | Total Energy = -2179.780889600173
# Step = 16800 | Total Energy = -2180.4614347062375
# Step = 16900 | Total Energy = -2180.9240091744546
# Step = 17000 | Total Energy = -2182.4056217488
# Step = 17100 | Total Energy = -2183.031664170351
# Step = 17200 | Total Energy = -2181.4599076406303
# Step = 17300 | Total Energy = -2180.5165129134025
# Step = 17400 | Total Energy = -2180.28142430846
# Step = 17500 | Total Energy = -2180.0034677145227
# Step = 17600 | Total Energy = -2180.2385742316687
# Step = 17700 | Total Energy = -2181.2228082219444
# Step = 17800 | Total Energy = -2181.9108183304184
# Step = 17900 | Total Energy = -2181.360431685039
# Step = 18000 | Total Energy = -2179.598708274652
# Step = 18100 | Total Energy = -2179.448870862877
# Step = 18200 | Total Energy = -2180.205605255017
# Step = 18300 | Total Energy = -2181.3786184126093
# Step = 18400 | Total Energy = -2182.021311553677
# Step = 18500 | Total Energy = -2181.3691139294237
# Step = 18600 | Total Energy = -2179.7364245455187
# Step = 18700 | Total Energy = -2179.0629334803025
# Step = 18800 | Total Energy = -2179.9493746850885
# Step = 18900 | Total Energy = -2181.234216993349
# Step = 19000 | Total Energy = -2181.5658894332028
# Step = 19100 | Total Energy = -2180.74601284394
# Step = 19200 | Total Energy = -2180.0184006984837
# Step = 19300 | Total Energy = -2179.957270667944
# Step = 19400 | Total Energy = -2180.4544878822435
# Step = 19500 | Total Energy = -2181.013174732967
# Step = 19600 | Total Energy = -2181.090986141118
# Step = 19700 | Total Energy = -2180.426556459772
# Step = 19800 | Total Energy = -2179.1573263851947
# Step = 19900 | Total Energy = -2179.1520791230173
# Step = 20000 | Total Energy = -2180.940911250174
# Step = 20100 | Total Energy = -2181.6917718319864
# Step = 20200 | Total Energy = -2181.095746208284
# Step = 20300 | Total Energy = -2180.3441077453926
# Step = 20400 | Total Energy = -2179.7877284621422
# Step = 20500 | Total Energy = -2179.4488666475468
# Step = 20600 | Total Energy = -2179.917628220918
# Step = 20700 | Total Energy = -2180.9323015066993
# Step = 20800 | Total Energy = -2181.6453938362547
# Step = 20900 | Total Energy = -2181.090518109639
# Step = 21000 | Total Energy = -2179.5788307001717
# Step = 21100 | Total Energy = -2179.245729290433
# Step = 21200 | Total Energy = -2179.942382693189
# Step = 21300 | Total Energy = -2180.2888954680425
# Step = 21400 | Total Energy = -2180.4895254545263
# Step = 21500 | Total Energy = -2180.722126486571
# Step = 21600 | Total Energy = -2180.325677224658
# Step = 21700 | Total Energy = -2179.258504087964
# Step = 21800 | Total Energy = -2178.9818128330176
# Step = 21900 | Total Energy = -2180.2320473176455
# Step = 22000 | Total Energy = -2181.3080396132605
# Step = 22100 | Total Energy = -2181.178970128029
# Step = 22200 | Total Energy = -2180.3982171095795
# Step = 22300 | Total Energy = -2179.064384099108
# Step = 22400 | Total Energy = -2177.3238944315494
# Step = 22500 | Total Energy = -2176.337406781393
# Step = 22600 | Total Energy = -2178.469221878742
# Step = 22700 | Total Energy = -2179.875707168582
# Step = 22800 | Total Energy = -2181.1326358163274
# Step = 22900 | Total Energy = -2181.432705625596
# Step = 23000 | Total Energy = -2180.7173695919514
# Step = 23100 | Total Energy = -2179.166441048558
# Step = 23200 | Total Energy = -2179.0005132404503
# Step = 23300 | Total Energy = -2179.872886170572
# Step = 23400 | Total Energy = -2180.2933876950215
# Step = 23500 | Total Energy = -2180.5836298286536
# Step = 23600 | Total Energy = -2180.7063386803407
# Step = 23700 | Total Energy = -2180.404820192758
# Step = 23800 | Total Energy = -2179.7563989258056
# Step = 23900 | Total Energy = -2179.2625233452736
# Step = 24000 | Total Energy = -2180.043094492573
# Step = 24100 | Total Energy = -2181.526298063897
# Step = 24200 | Total Energy = -2181.6682864501604
# Step = 24300 | Total Energy = -2180.808947523616
# Step = 24400 | Total Energy = -2180.468147063572
# Step = 24500 | Total Energy = -2180.2652033716518
# Step = 24600 | Total Energy = -2180.3408229714464
# Step = 24700 | Total Energy = -2180.740191629959
# Step = 24800 | Total Energy = -2181.550536283204
# Step = 24900 | Total Energy = -2181.781041007075
# Step = 25000 | Total Energy = -2180.509558604764
# Step = 25100 | Total Energy = -2179.341957603304
# Step = 25200 | Total Energy = -2179.542524432475
# Step = 25300 | Total Energy = -2180.4369748211966
# Step = 25400 | Total Energy = -2180.9004149597945
# Step = 25500 | Total Energy = -2180.836708733803
# Step = 25600 | Total Energy = -2180.6297020323564
# Step = 25700 | Total Energy = -2180.2369597150328
# Step = 25800 | Total Energy = -2179.9004650544134
# Step = 25900 | Total Energy = -2179.0996497067017
# Step = 26000 | Total Energy = -2179.2712645630063
# Step = 26100 | Total Energy = -2180.6585614279134
# Step = 26200 | Total Energy = -2181.547979907877
# Step = 26300 | Total Energy = -2181.1216016525436
# Step = 26400 | Total Energy = -2180.2361883382428
# Step = 26500 | Total Energy = -2179.6978942954374
# Step = 26600 | Total Energy = -2179.9614088125995
# Step = 26700 | Total Energy = -2180.393312322612
# Step = 26800 | Total Energy = -2181.006945434016
# Step = 26900 | Total Energy = -2181.4934138942913
# Step = 27000 | Total Energy = -2181.28418216322
# Step = 27100 | Total Energy = -2179.772753310013
# Step = 27200 | Total Energy = -2179.0413300724263
# Step = 27300 | Total Energy = -2179.746716015735
# Step = 27400 | Total Energy = -2181.2234414333157
# Step = 27500 | Total Energy = -2181.2906426201175
# Step = 27600 | Total Energy = -2180.7976666701907
# Step = 27700 | Total Energy = -2180.055786859656
# Step = 27800 | Total Energy = -2179.507725966511
# Step = 27900 | Total Energy = -2179.2981329601107
# Step = 28000 | Total Energy = -2180.2766478338945
# Step = 28100 | Total Energy = -2181.2562722072516
# Step = 28200 | Total Energy = -2181.6410840402273
# Step = 28300 | Total Energy = -2180.5294275810315
# Step = 28400 | Total Energy = -2179.0755416708325
# Step = 28500 | Total Energy = -2179.4338303974287
# Step = 28600 | Total Energy = -2180.2816354769902
# Step = 28700 | Total Energy = -2180.741454706569
# Step = 28800 | Total Energy = -2180.8179967715223
# Step = 28900 | Total Energy = -2180.5614413065514
# Step = 29000 | Total Energy = -2180.3721058024116
# Step = 29100 | Total Energy = -2180.460922832073
# Step = 29200 | Total Energy = -2180.3840779535217
# Step = 29300 | Total Energy = -2180.346162482333
# Step = 29400 | Total Energy = -2180.338859940968
# Step = 29500 | Total Energy = -2180.221384562568
# Step = 29600 | Total Energy = -2180.508681776469
# Step = 29700 | Total Energy = -2180.8105149828
# Step = 29800 | Total Energy = -2181.217808336682
# Step = 29900 | Total Energy = -2181.1258411325684
# Step = 30000 | Total Energy = -2179.9400905231482
# Step = 30100 | Total Energy = -2178.8997322092514
# Step = 30200 | Total Energy = -2179.4579313966865
# Step = 30300 | Total Energy = -2181.4277253904875
# Step = 30400 | Total Energy = -2181.5276256987336
# Step = 30500 | Total Energy = -2180.737171101763
# Step = 30600 | Total Energy = -2179.7085252822253
# Step = 30700 | Total Energy = -2179.3910922991545
# Step = 30800 | Total Energy = -2180.809054287732
# Step = 30900 | Total Energy = -2182.2660233682695
# Step = 31000 | Total Energy = -2181.5405911779344
# Step = 31100 | Total Energy = -2180.2591555700174
# Step = 31200 | Total Energy = -2179.873418378576
# Step = 31300 | Total Energy = -2179.952217589401
# Step = 31400 | Total Energy = -2181.427497133741
# Step = 31500 | Total Energy = -2182.7735153177946
# Step = 31600 | Total Energy = -2182.0522963655408
# Step = 31700 | Total Energy = -2180.997934301152
# Step = 31800 | Total Energy = -2180.346219877636
# Step = 31900 | Total Energy = -2179.735363894711
# Step = 32000 | Total Energy = -2179.850394103169
# Step = 32100 | Total Energy = -2181.1963016892278
# Step = 32200 | Total Energy = -2181.9920627241127
# Step = 32300 | Total Energy = -2181.375234064393
# Step = 32400 | Total Energy = -2179.781100129329
# Step = 32500 | Total Energy = -2179.584326815367
# Step = 32600 | Total Energy = -2180.165885687502
# Step = 32700 | Total Energy = -2180.956509484838
# Step = 32800 | Total Energy = -2182.2916986142795
# Step = 32900 | Total Energy = -2183.829259447517
# Step = 33000 | Total Energy = -2182.6421077080017
# Step = 33100 | Total Energy = -2181.234034590762
# Step = 33200 | Total Energy = -2180.492479345925
# Step = 33300 | Total Energy = -2179.5578875613414
# Step = 33400 | Total Energy = -2179.562482829947
# Step = 33500 | Total Energy = -2180.805135092338
# Step = 33600 | Total Energy = -2181.8791932602307
# Step = 33700 | Total Energy = -2181.4867180356728
# Step = 33800 | Total Energy = -2180.5964088566066
# Step = 33900 | Total Energy = -2180.290159872262
# Step = 34000 | Total Energy = -2180.3429576533804
# Step = 34100 | Total Energy = -2180.506191696517
# Step = 34200 | Total Energy = -2181.0731949848278
# Step = 34300 | Total Energy = -2181.9618612473205
# Step = 34400 | Total Energy = -2181.7029406913807
# Step = 34500 | Total Energy = -2179.993899131354
# Step = 34600 | Total Energy = -2179.469879521894
# Step = 34700 | Total Energy = -2179.9375225387907
# Step = 34800 | Total Energy = -2180.917442710966
# Step = 34900 | Total Energy = -2181.9831509814576
# Step = 35000 | Total Energy = -2183.754203675197
# Step = 35100 | Total Energy = -2182.867456848446
# Step = 35200 | Total Energy = -2181.5133986717065
# Step = 35300 | Total Energy = -2180.5298809671863
# Step = 35400 | Total Energy = -2179.6900859105017
# Step = 35500 | Total Energy = -2179.492497499998
# Step = 35600 | Total Energy = -2180.668916320357
# Step = 35700 | Total Energy = -2181.9265595203055
# Step = 35800 | Total Energy = -2181.582209502112
# Step = 35900 | Total Energy = -2180.620497027702
# Step = 36000 | Total Energy = -2180.158910000597
# Step = 36100 | Total Energy = -2180.28197184573
# Step = 36200 | Total Energy = -2180.4468377483927
# Step = 36300 | Total Energy = -2181.0937241425663
# Step = 36400 | Total Energy = -2182.2451221262722
# Step = 36500 | Total Energy = -2181.7426966362355
# Step = 36600 | Total Energy = -2179.998077329935
# Step = 36700 | Total Energy = -2179.7550270916413
# Step = 36800 | Total Energy = -2180.1255216478253
# Step = 36900 | Total Energy = -2181.0723674681794
# Step = 37000 | Total Energy = -2182.540762876228
# Step = 37100 | Total Energy = -2182.722259663182
# Step = 37200 | Total Energy = -2180.481114384931
# Step = 37300 | Total Energy = -2179.697344052769
# Step = 37400 | Total Energy = -2179.6046641654275
# Step = 37500 | Total Energy = -2180.5261764370216
# Step = 37600 | Total Energy = -2181.5721908025494
# Step = 37700 | Total Energy = -2181.7715747380894
# Step = 37800 | Total Energy = -2179.7995487683957
# Step = 37900 | Total Energy = -2179.1633784848327
# Step = 38000 | Total Energy = -2179.8363304513755
# Step = 38100 | Total Energy = -2181.144223087734
# Step = 38200 | Total Energy = -2181.3894654136648
# Step = 38300 | Total Energy = -2180.8048372039775
# Step = 38400 | Total Energy = -2179.773839927629
# Step = 38500 | Total Energy = -2177.187133745902
# Step = 38600 | Total Energy = -2177.44131553063
# Step = 38700 | Total Energy = -2179.1208970227954
# Step = 38800 | Total Energy = -2180.4646688746634
# Step = 38900 | Total Energy = -2181.1811793756706
# Step = 39000 | Total Energy = -2181.2203665680545
# Step = 39100 | Total Energy = -2179.9672681888696
# Step = 39200 | Total Energy = -2178.688998526089
# Step = 39300 | Total Energy = -2179.21803967687
# Step = 39400 | Total Energy = -2180.1779298712204
# Step = 39500 | Total Energy = -2180.526955360243
# Step = 39600 | Total Energy = -2180.5706487835214
# Step = 39700 | Total Energy = -2180.5306176552813
# Step = 39800 | Total Energy = -2180.1670390841236
# Step = 39900 | Total Energy = -2179.6282265510026
# Step = 40000 | Total Energy = -2179.5514379432316
# Step = 40100 | Total Energy = -2180.52716663448
# Step = 40200 | Total Energy = -2181.6610549911097
# Step = 40300 | Total Energy = -2181.4850956319906
# Step = 40400 | Total Energy = -2179.637571577067
# Step = 40500 | Total Energy = -2179.0835965517495
# Step = 40600 | Total Energy = -2179.800710969705
# Step = 40700 | Total Energy = -2180.798100045663
# Step = 40800 | Total Energy = -2181.3555684596968
# Step = 40900 | Total Energy = -2180.7143697734264
# Step = 41000 | Total Energy = -2178.5374796773717
# Step = 41100 | Total Energy = -2178.9231358215084
# Step = 41200 | Total Energy = -2180.2176503460805
# Step = 41300 | Total Energy = -2180.9907737250637
# Step = 41400 | Total Energy = -2180.9176256562964
# Step = 41500 | Total Energy = -2180.3385880876785
# Step = 41600 | Total Energy = -2178.4248172945395
# Step = 41700 | Total Energy = -2177.982178469608
# Step = 41800 | Total Energy = -2179.0716832117364
# Step = 41900 | Total Energy = -2180.1653689209134
# Step = 42000 | Total Energy = -2180.7049005132667
# Step = 42100 | Total Energy = -2180.966980691818
# Step = 42200 | Total Energy = -2180.8405226009995
# Step = 42300 | Total Energy = -2179.582350457348
# Step = 42400 | Total Energy = -2178.8862971721533
# Step = 42500 | Total Energy = -2179.802302546152
# Step = 42600 | Total Energy = -2181.368756816895
# Step = 42700 | Total Energy = -2181.4020879263608
# Step = 42800 | Total Energy = -2180.6905457715125
# Step = 42900 | Total Energy = -2179.968677607179
# Step = 43000 | Total Energy = -2179.4431475589195
# Step = 43100 | Total Energy = -2179.0762748868347
# Step = 43200 | Total Energy = -2179.6637324086264
# Step = 43300 | Total Energy = -2181.0613280288994
# Step = 43400 | Total Energy = -2181.49653484967
# Step = 43500 | Total Energy = -2180.9044223842457
# Step = 43600 | Total Energy = -2179.140750053487
# Step = 43700 | Total Energy = -2179.0785896446996
# Step = 43800 | Total Energy = -2179.897349729248
# Step = 43900 | Total Energy = -2180.496259194989
# Step = 44000 | Total Energy = -2180.6691392115968
# Step = 44100 | Total Energy = -2180.5777099611646
# Step = 44200 | Total Energy = -2180.303209801061
# Step = 44300 | Total Energy = -2179.2112529208325
# Step = 44400 | Total Energy = -2178.14285813297
# Step = 44500 | Total Energy = -2179.374897083949
# Step = 44600 | Total Energy = -2180.755263192207
# Step = 44700 | Total Energy = -2181.0375517144757
# Step = 44800 | Total Energy = -2180.5994490471567
# Step = 44900 | Total Energy = -2179.2980665208784
# Step = 45000 | Total Energy = -2177.886937006765
# Step = 45100 | Total Energy = -2178.8755805240803
# Step = 45200 | Total Energy = -2179.767962855355
# Step = 45300 | Total Energy = -2180.4707308885404
# Step = 45400 | Total Energy = -2180.978811880158
# Step = 45500 | Total Energy = -2181.183763576738
# Step = 45600 | Total Energy = -2180.534402264519
# Step = 45700 | Total Energy = -2179.2852393259295
# Step = 45800 | Total Energy = -2179.011724569278
# Step = 45900 | Total Energy = -2180.4495313295984
# Step = 46000 | Total Energy = -2181.5853230452603
# Step = 46100 | Total Energy = -2181.2543480385307
# Step = 46200 | Total Energy = -2180.3962672211173
# Step = 46300 | Total Energy = -2179.734477320654
# Step = 46400 | Total Energy = -2179.345126242465
# Step = 46500 | Total Energy = -2180.212718957324
# Step = 46600 | Total Energy = -2181.4242401254623
# Step = 46700 | Total Energy = -2181.7047943775224
# Step = 46800 | Total Energy = -2180.5404156212317
# Step = 46900 | Total Energy = -2179.4688408174293
# Step = 47000 | Total Energy = -2179.5018379448597
# Step = 47100 | Total Energy = -2180.1714959909377
# Step = 47200 | Total Energy = -2180.424013594162
# Step = 47300 | Total Energy = -2180.5600328293326
# Step = 47400 | Total Energy = -2180.513250025135
# Step = 47500 | Total Energy = -2180.103915995335
# Step = 47600 | Total Energy = -2179.1164344198987
# Step = 47700 | Total Energy = -2178.9862205976942
# Step = 47800 | Total Energy = -2180.4584739919233
# Step = 47900 | Total Energy = -2181.3791001834734
# Step = 48000 | Total Energy = -2181.1101838932063
# Step = 48100 | Total Energy = -2180.34249704304
# Step = 48200 | Total Energy = -2178.950769843967
# Step = 48300 | Total Energy = -2176.723222741797
# Step = 48400 | Total Energy = -2177.03304070984
# Step = 48500 | Total Energy = -2178.65637933736
# Step = 48600 | Total Energy = -2179.9211850204215
# Step = 48700 | Total Energy = -2181.2169785136807
# Step = 48800 | Total Energy = -2181.3346784578866
# Step = 48900 | Total Energy = -2180.5239397141295
# Step = 49000 | Total Energy = -2179.190126344954
# Step = 49100 | Total Energy = -2179.1829904167184
# Step = 49200 | Total Energy = -2180.074218287305
# Step = 49300 | Total Energy = -2180.4686903708807
# Step = 49400 | Total Energy = -2180.438730575256
# Step = 49500 | Total Energy = -2180.4555860214314
# Step = 49600 | Total Energy = -2180.287304347446
# Step = 49700 | Total Energy = -2179.8929287270903
# Step = 49800 | Total Energy = -2179.685152035865
# Step = 49900 | Total Energy = -2180.2079935285037

# %%
# Check if neighbors overflowed
print(nbrs_r.did_buffer_overflow)
# Out:
# 0

# %% [markdown]
# ## Comparison plot

# %% [markdown]
# Note that you have to reconvert the units again.

# %%
Nsteps = int(steps/write_every)
t = jnp.arange(0, Nsteps,dtype=f64) * timestep * write_every

# %%
plt.style.use('seaborn-dark-palette')
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams.update({'font.size': 12})
fig = plt.figure(figsize=(16, 8))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(t, log_r['kT'] / unit['temperature'], lw=4, label='JAX MD')
ax1.plot(t_l, T, lw=2, label='LAMMPS')
ax1.set_title('Temperature', fontsize=16)
ax1.set_ylabel("$T\ (K)$", fontsize=16)
ax1.set_xlabel("$t\ (ps)$", fontsize=16)
ax1.legend()

ax2 = plt.subplot(2, 2, 2)
ax2.plot(t, (log_r['P'] / unit['pressure']) / 10000, lw=4, label='JAX MD')
ax2.plot(t_l, P/10000, lw=2, label='LAMMPS')
ax2.set_title('Pressure', fontsize=16)
ax2.set_ylabel("$P\ (GPa)$", fontsize=16)
ax2.set_xlabel("$t\ (ps)$", fontsize=16)
ax2.legend()

ax3 = plt.subplot(2, 2, 3)
ax3.plot(t, log_r['E'], lw=4, label='JAX MD')
ax3.plot(t_l, E, lw=2, label='LAMMPS')
ax3.set_title('Potential Energy', fontsize=16)
ax3.set_ylabel("$E_{PE}\ (eV)$", fontsize=16)
ax3.set_xlabel("$t\ (ps)$", fontsize=16)
ax3.legend()

ax4 = plt.subplot(2, 2, 4)
ax4.plot(t, log_r['T']/512, lw=4, label='JAX MD')
ax4.plot(t_l, H/512, lw=2, label='LAMMPS')
ax4.set_title('Constant of motion', fontsize=16)
ax4.set_ylabel("$E_{T}\ (eV/Atom)$", fontsize=16)
ax4.set_xlabel("$t\ (ps)$", fontsize=16)
ax4.set_ylim(jnp.mean(log_r['T']/512) - jnp.mean(log_r['T']/512)/1000 , jnp.mean(log_r['T']/512) + jnp.mean(log_r['T']/512)/1000)
ax4.legend()

fig.tight_layout()
