# %%
#@title Imports & Utils

# !pip install -q git+https://www.github.com/google/jax-md
import jax.numpy as jnp
import numpy as onp
from jax import debug
from jax import jit
from jax import grad
from jax import random
from jax import lax
from jax.config import config

config.update('jax_enable_x64', True)
from jax_md import simulate
from jax_md import space
from jax_md import energy
from jax_md import elasticity
from jax_md import quantity
from jax_md import dataclasses
from jax_md.util import f64

# Other libraries
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from typing import Callable, Tuple, TextIO, Dict, Any, Optional, TypeVar

# LAMMPS data
# !wget https://raw.githubusercontent.com/abhijeetgangan/silicon_data/main/Si_FF/Si_SW_MD/NVT_berendsen_300K/lammps_nvt.dat
# !wget https://raw.githubusercontent.com/abhijeetgangan/silicon_data/main/Si_FF/Si_SW_MD/NVE_300K/step_1.traj
data_lammps = pd.read_csv("lammps_nvt.dat", delim_whitespace="  ", header=None)
data_lammps = data_lammps.dropna(axis=1)
data_lammps.columns = ['Time','T','P','V','E','H']
t_l, T_l, P_l, V_l, E_l, H_l = data_lammps['Time'], data_lammps['T'], data_lammps['P'], data_lammps['V'], data_lammps['E'], data_lammps['H']
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.5/152.5 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.3/360.3 kB 7.4 MB/s eta 0:00:00
#   Building wheel for jax-md (setup.py) ... done
#   Building wheel for ml_collections (setup.py) ... done
# --2023-08-18 05:46:01--  https://raw.githubusercontent.com/abhijeetgangan/silicon_data/main/Si_FF/Si_SW_MD/NVT_berendsen_300K/lammps_nvt.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39579 (39K) [text/plain]
# Saving to: ‘lammps_nvt.dat’
#
# lammps_nvt.dat      100%[===================>]  38.65K  --.-KB/s    in 0.002s
#
# 2023-08-18 05:46:02 (16.3 MB/s) - ‘lammps_nvt.dat’ saved [39579/39579]
#
# --2023-08-18 05:46:02--  https://raw.githubusercontent.com/abhijeetgangan/silicon_data/main/Si_FF/Si_SW_MD/NVE_300K/step_1.traj
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64303 (63K) [text/plain]
# Saving to: ‘step_1.traj’
#
# step_1.traj         100%[===================>]  62.80K  --.-KB/s    in 0.006s
#
# 2023-08-18 05:46:02 (10.3 MB/s) - ‘step_1.traj’ saved [64303/64303]

# %%
lammps_step_0 = onp.loadtxt('/content/step_1.traj', dtype=f64)
# Load positions from lammps
positions = jnp.array(lammps_step_0[:,2:5], dtype=f64)
# Load velocities from lammps
velocity = jnp.array(lammps_step_0[:,5:8], dtype=f64)
latvec = jnp.array([[21.724, 0.000000, 0.000000], [0.00000, 21.724, 0.00000],[0.00000, 0.0000, 21.724]])

# %%
# Import unit system
from jax_md import units

# Metal units
unit = units.metal_unit_system()

# Simulation parameters
timestep = 1e-3
fs = timestep * unit['time']
ps = unit['time']
dt = fs
write_every = 100
box = latvec
T_init = 300 * unit['temperature']
Mass = 28.0855 * unit['mass']
key = random.PRNGKey(121)
steps = 50000

# %%
# Logger to save data
log = {
'E': jnp.zeros((steps // write_every,)),
'P': jnp.zeros((steps // write_every,)),
'T': jnp.zeros((steps // write_every,)),
'kT': jnp.zeros((steps // write_every,)),
}

# %%
# Setup the periodic boundary conditions.
displacement, shift = space.periodic_general(latvec)
dist_fun = space.metric(displacement)
neighbor_fn, energy_fn = energy.stillinger_weber_neighbor_list(displacement, latvec, disable_cell_list=True)
energy_fn = jit(energy_fn)

# %%
# Extra capacity to prevent overflow
nbrs = neighbor_fn.allocate(positions, box=box, extra_capacity=2)

# Brenderson simulation
init_fn, apply_fn = simulate.temp_berendsen(energy_fn, shift, dt=dt, kT=T_init, tau=100 * dt)
apply_fn = jit(apply_fn)
state = init_fn(key, positions, box=box, neighbor=nbrs, kT=T_init, mass=Mass)

# Restart from LAMMPS velocities
state = dataclasses.replace(state, momentum = Mass * velocity * unit['velocity'])
# Out:
# /usr/local/lib/python3.10/dist-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int64 to dtype=int32. In future JAX releases this will result in an error.
#   warnings.warn("scatter inputs have incompatible types: cannot safely cast "

# %%
@jit
def step_fn(i, state_nbrs):
  state, nbrs = state_nbrs
  # Take a simulation step.
  t = i * dt
  state = apply_fn(state, neighbor=nbrs, kT=T_init)
  nbrs = nbrs.update(state.position, neighbor=nbrs)
  return state, nbrs

@jit
def outer_sim_fn(j, state_nbrs_log):
  state, nbrs, log = state_nbrs_log

  # Quantities to calculate
  K  = quantity.kinetic_energy(momentum = state.momentum, mass=Mass)
  E  = energy_fn(state.position, box=box, neighbor=nbrs)
  kT = quantity.temperature(momentum = state.momentum, mass=Mass)
  P  = quantity.pressure(energy_fn, state.position, box, K, neighbor=nbrs)

  # Save the quantities
  log['T'] = log['T'].at[j].set(E + K)
  log['E'] = log['E'].at[j].set(E)
  log['kT'] = log['kT'].at[j].set(kT)
  log['P'] = log['P'].at[j].set(P)

  # Print the quantities
  debug.print('Step = {j} | Total Energy = {T}', j=j*write_every, T = K + E)

  @jit
  def inner_sim_fn(i, state_nbrs):
    return step_fn(i, state_nbrs)

  state, nbrs = lax.fori_loop(0, write_every, inner_sim_fn, (state, nbrs))

  return state, nbrs, log

# %%
state_r, nbrs_r, log_r = lax.fori_loop(0, int(steps/write_every), outer_sim_fn, (state, nbrs, log))
# Out:
# /usr/local/lib/python3.10/dist-packages/jax/_src/ops/scatter.py:93: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int64 to dtype=int32. In future JAX releases this will result in an error.
#   warnings.warn("scatter inputs have incompatible types: cannot safely cast "
# Step = 0 | Total Energy = -2200.4826561382038
# Step = 100 | Total Energy = -2192.676199365296
# Step = 200 | Total Energy = -2187.6722858487806
# Step = 300 | Total Energy = -2184.7917665854625
# Step = 400 | Total Energy = -2183.06516735821
# Step = 500 | Total Energy = -2182.0124991793064
# Step = 600 | Total Energy = -2181.381690467812
# Step = 700 | Total Energy = -2181.145585174738
# Step = 800 | Total Energy = -2180.850808954208
# Step = 900 | Total Energy = -2180.5797977994716
# Step = 1000 | Total Energy = -2180.6378101033893
# Step = 1100 | Total Energy = -2180.7181987147233
# Step = 1200 | Total Energy = -2180.6952291423268
# Step = 1300 | Total Energy = -2180.533014464813
# Step = 1400 | Total Energy = -2180.475627561999
# Step = 1500 | Total Energy = -2180.200837069484
# Step = 1600 | Total Energy = -2180.4709442881795
# Step = 1700 | Total Energy = -2180.5139942293376
# Step = 1800 | Total Energy = -2180.3833400122094
# Step = 1900 | Total Energy = -2180.251206615192
# Step = 2000 | Total Energy = -2180.3050536440333
# Step = 2100 | Total Energy = -2180.522567053474
# Step = 2200 | Total Energy = -2180.340332233151
# Step = 2300 | Total Energy = -2180.713674832515
# Step = 2400 | Total Energy = -2180.6288530181046
# Step = 2500 | Total Energy = -2180.438417343001
# Step = 2600 | Total Energy = -2180.5341653580062
# Step = 2700 | Total Energy = -2180.3652838322405
# Step = 2800 | Total Energy = -2180.2810664287504
# Step = 2900 | Total Energy = -2180.4136783540575
# Step = 3000 | Total Energy = -2180.2506049342323
# Step = 3100 | Total Energy = -2180.033338924015
# Step = 3200 | Total Energy = -2180.340802231812
# Step = 3300 | Total Energy = -2180.197235462194
# Step = 3400 | Total Energy = -2180.757023635859
# Step = 3500 | Total Energy = -2180.4890621171544
# Step = 3600 | Total Energy = -2180.3886244242126
# Step = 3700 | Total Energy = -2180.5971990682365
# Step = 3800 | Total Energy = -2180.2265431856595
# Step = 3900 | Total Energy = -2180.276136192157
# Step = 4000 | Total Energy = -2180.478962245414
# Step = 4100 | Total Energy = -2180.2432565662943
# Step = 4200 | Total Energy = -2180.3603478434243
# Step = 4300 | Total Energy = -2180.7163864267122
# Step = 4400 | Total Energy = -2180.2491508160406
# Step = 4500 | Total Energy = -2180.4479419400345
# Step = 4600 | Total Energy = -2180.496171420809
# Step = 4700 | Total Energy = -2180.2388106108506
# Step = 4800 | Total Energy = -2180.4907415900007
# Step = 4900 | Total Energy = -2180.255842711095
# Step = 5000 | Total Energy = -2180.368864688071
# Step = 5100 | Total Energy = -2180.4623171907397
# Step = 5200 | Total Energy = -2180.638235364762
# Step = 5300 | Total Energy = -2180.575445551588
# Step = 5400 | Total Energy = -2180.590811070543
# Step = 5500 | Total Energy = -2180.453768224264
# Step = 5600 | Total Energy = -2180.457494553157
# Step = 5700 | Total Energy = -2180.2477151409576
# Step = 5800 | Total Energy = -2180.209830407028
# Step = 5900 | Total Energy = -2180.546644382492
# Step = 6000 | Total Energy = -2180.430849173901
# Step = 6100 | Total Energy = -2180.5675234789683
# Step = 6200 | Total Energy = -2180.611190446599
# Step = 6300 | Total Energy = -2180.3838783312935
# Step = 6400 | Total Energy = -2180.463039989077
# Step = 6500 | Total Energy = -2180.3137699647527
# Step = 6600 | Total Energy = -2180.57762227144
# Step = 6700 | Total Energy = -2180.4055498479684
# Step = 6800 | Total Energy = -2180.474868267313
# Step = 6900 | Total Energy = -2180.2556496338443
# Step = 7000 | Total Energy = -2180.4559551238217
# Step = 7100 | Total Energy = -2180.205372519056
# Step = 7200 | Total Energy = -2180.370653043385
# Step = 7300 | Total Energy = -2180.621130347306
# Step = 7400 | Total Energy = -2180.284441164348
# Step = 7500 | Total Energy = -2180.57285153133
# Step = 7600 | Total Energy = -2180.271644706636
# Step = 7700 | Total Energy = -2180.2219241313323
# Step = 7800 | Total Energy = -2180.632032914891
# Step = 7900 | Total Energy = -2180.623409654498
# Step = 8000 | Total Energy = -2180.3924640204755
# Step = 8100 | Total Energy = -2180.4107228911453
# Step = 8200 | Total Energy = -2180.467630511903
# Step = 8300 | Total Energy = -2180.061580581158
# Step = 8400 | Total Energy = -2180.6280530927925
# Step = 8500 | Total Energy = -2180.224566478737
# Step = 8600 | Total Energy = -2180.247039281432
# Step = 8700 | Total Energy = -2180.3049476209408
# Step = 8800 | Total Energy = -2180.2344545049286
# Step = 8900 | Total Energy = -2180.432389062066
# Step = 9000 | Total Energy = -2180.6315544050367
# Step = 9100 | Total Energy = -2180.5883506379632
# Step = 9200 | Total Energy = -2180.5790568483494
# Step = 9300 | Total Energy = -2180.5435253475903
# Step = 9400 | Total Energy = -2180.278494633352
# Step = 9500 | Total Energy = -2180.5029378247136
# Step = 9600 | Total Energy = -2180.510359586962
# Step = 9700 | Total Energy = -2180.4051464304725
# Step = 9800 | Total Energy = -2180.538882552545
# Step = 9900 | Total Energy = -2180.364129011495
# Step = 10000 | Total Energy = -2180.4181211405867
# Step = 10100 | Total Energy = -2180.3794736635546
# Step = 10200 | Total Energy = -2180.4060948787264
# Step = 10300 | Total Energy = -2180.1825688973086
# Step = 10400 | Total Energy = -2180.5406789190274
# Step = 10500 | Total Energy = -2180.5037912202765
# Step = 10600 | Total Energy = -2180.448691932661
# Step = 10700 | Total Energy = -2180.472044069512
# Step = 10800 | Total Energy = -2180.596152275113
# Step = 10900 | Total Energy = -2180.4408329804996
# Step = 11000 | Total Energy = -2180.626183961247
# Step = 11100 | Total Energy = -2180.5766886584042
# Step = 11200 | Total Energy = -2180.3452263857785
# Step = 11300 | Total Energy = -2180.354962369443
# Step = 11400 | Total Energy = -2180.202766701855
# Step = 11500 | Total Energy = -2180.087464026497
# Step = 11600 | Total Energy = -2180.5007630678506
# Step = 11700 | Total Energy = -2180.480240069186
# Step = 11800 | Total Energy = -2180.540238645638
# Step = 11900 | Total Energy = -2180.485991766107
# Step = 12000 | Total Energy = -2180.4121975404355
# Step = 12100 | Total Energy = -2180.323105772287
# Step = 12200 | Total Energy = -2180.5116354663232
# Step = 12300 | Total Energy = -2180.3480082360884
# Step = 12400 | Total Energy = -2180.3350693173816
# Step = 12500 | Total Energy = -2180.350025569109
# Step = 12600 | Total Energy = -2180.3273433265335
# Step = 12700 | Total Energy = -2180.4748183322668
# Step = 12800 | Total Energy = -2180.589985357104
# Step = 12900 | Total Energy = -2180.4194257159857
# Step = 13000 | Total Energy = -2180.4374744260194
# Step = 13100 | Total Energy = -2180.4051785154797
# Step = 13200 | Total Energy = -2180.257315403759
# Step = 13300 | Total Energy = -2180.2513170520074
# Step = 13400 | Total Energy = -2180.4887393433983
# Step = 13500 | Total Energy = -2180.3632004334927
# Step = 13600 | Total Energy = -2180.5863186771467
# Step = 13700 | Total Energy = -2180.468796012223
# Step = 13800 | Total Energy = -2180.4855611289927
# Step = 13900 | Total Energy = -2180.3664695279144
# Step = 14000 | Total Energy = -2180.477245429729
# Step = 14100 | Total Energy = -2180.248894189703
# Step = 14200 | Total Energy = -2180.468697114661
# Step = 14300 | Total Energy = -2180.4821662918575
# Step = 14400 | Total Energy = -2180.4772120026546
# Step = 14500 | Total Energy = -2180.4883783740624
# Step = 14600 | Total Energy = -2180.4870093947425
# Step = 14700 | Total Energy = -2180.4918679107504
# Step = 14800 | Total Energy = -2180.5136218892253
# Step = 14900 | Total Energy = -2180.5791670638673
# Step = 15000 | Total Energy = -2180.3338324865176
# Step = 15100 | Total Energy = -2180.3642028243867
# Step = 15200 | Total Energy = -2180.3879724420462
# Step = 15300 | Total Energy = -2180.316168263823
# Step = 15400 | Total Energy = -2180.518198472921
# Step = 15500 | Total Energy = -2180.2784423521725
# Step = 15600 | Total Energy = -2180.5064188649244
# Step = 15700 | Total Energy = -2180.470217273719
# Step = 15800 | Total Energy = -2180.4647908527436
# Step = 15900 | Total Energy = -2180.3336898899256
# Step = 16000 | Total Energy = -2180.6638146593527
# Step = 16100 | Total Energy = -2180.449907359968
# Step = 16200 | Total Energy = -2180.4185149794407
# Step = 16300 | Total Energy = -2180.4596463447474
# Step = 16400 | Total Energy = -2180.2865008008303
# Step = 16500 | Total Energy = -2180.3937316493702
# Step = 16600 | Total Energy = -2180.3977208420856
# Step = 16700 | Total Energy = -2180.394258756329
# Step = 16800 | Total Energy = -2180.407822594208
# Step = 16900 | Total Energy = -2180.348715369111
# Step = 17000 | Total Energy = -2180.3404743398137
# Step = 17100 | Total Energy = -2180.356055177795
# Step = 17200 | Total Energy = -2180.55350425334
# Step = 17300 | Total Energy = -2180.3875670541547
# Step = 17400 | Total Energy = -2180.515400722273
# Step = 17500 | Total Energy = -2180.395713730122
# Step = 17600 | Total Energy = -2180.425923355396
# Step = 17700 | Total Energy = -2180.3452382264786
# Step = 17800 | Total Energy = -2180.4295354796627
# Step = 17900 | Total Energy = -2180.4776337306193
# Step = 18000 | Total Energy = -2180.4406379593943
# Step = 18100 | Total Energy = -2180.354709258569
# Step = 18200 | Total Energy = -2180.365460375636
# Step = 18300 | Total Energy = -2180.454049143871
# Step = 18400 | Total Energy = -2180.456283142138
# Step = 18500 | Total Energy = -2180.4409297149264
# Step = 18600 | Total Energy = -2180.4575804195943
# Step = 18700 | Total Energy = -2180.3445261142924
# Step = 18800 | Total Energy = -2180.4098257862797
# Step = 18900 | Total Energy = -2180.3286493742785
# Step = 19000 | Total Energy = -2180.608612648534
# Step = 19100 | Total Energy = -2180.4159072284788
# Step = 19200 | Total Energy = -2180.4854959697095
# Step = 19300 | Total Energy = -2180.471226998122
# Step = 19400 | Total Energy = -2180.4942755234983
# Step = 19500 | Total Energy = -2180.426113423965
# Step = 19600 | Total Energy = -2180.4127469723076
# Step = 19700 | Total Energy = -2180.304683948261
# Step = 19800 | Total Energy = -2180.447904009635
# Step = 19900 | Total Energy = -2180.4890182782774
# Step = 20000 | Total Energy = -2180.3433513462246
# Step = 20100 | Total Energy = -2180.5655325396856
# Step = 20200 | Total Energy = -2180.4715497523825
# Step = 20300 | Total Energy = -2180.40455813524
# Step = 20400 | Total Energy = -2180.5574926604263
# Step = 20500 | Total Energy = -2180.370119341119
# Step = 20600 | Total Energy = -2180.388639482901
# Step = 20700 | Total Energy = -2180.315793584108
# Step = 20800 | Total Energy = -2180.3688097284044
# Step = 20900 | Total Energy = -2180.3724069230666
# Step = 21000 | Total Energy = -2180.583655809706
# Step = 21100 | Total Energy = -2180.4327197265447
# Step = 21200 | Total Energy = -2180.5530894812455
# Step = 21300 | Total Energy = -2180.3779719585596
# Step = 21400 | Total Energy = -2180.308481481394
# Step = 21500 | Total Energy = -2180.4271072315264
# Step = 21600 | Total Energy = -2180.4481900425203
# Step = 21700 | Total Energy = -2180.4380044931117
# Step = 21800 | Total Energy = -2180.376993981777
# Step = 21900 | Total Energy = -2180.3815997793495
# Step = 22000 | Total Energy = -2180.3284855529632
# Step = 22100 | Total Energy = -2180.463139028533
# Step = 22200 | Total Energy = -2180.542342834989
# Step = 22300 | Total Energy = -2180.4329772898827
# Step = 22400 | Total Energy = -2180.3938410411
# Step = 22500 | Total Energy = -2180.3295556332296
# Step = 22600 | Total Energy = -2180.3200864342643
# Step = 22700 | Total Energy = -2180.387457889705
# Step = 22800 | Total Energy = -2180.5837252789306
# Step = 22900 | Total Energy = -2180.4013203188133
# Step = 23000 | Total Energy = -2180.584264096786
# Step = 23100 | Total Energy = -2180.455690359099
# Step = 23200 | Total Energy = -2180.3999462242123
# Step = 23300 | Total Energy = -2180.430666194409
# Step = 23400 | Total Energy = -2180.458863049545
# Step = 23500 | Total Energy = -2180.3968182583903
# Step = 23600 | Total Energy = -2180.4239756016964
# Step = 23700 | Total Energy = -2180.491139797938
# Step = 23800 | Total Energy = -2180.374116925284
# Step = 23900 | Total Energy = -2180.4485578262525
# Step = 24000 | Total Energy = -2180.4153680197087
# Step = 24100 | Total Energy = -2180.3930561181865
# Step = 24200 | Total Energy = -2180.5386175896538
# Step = 24300 | Total Energy = -2180.4557690119
# Step = 24400 | Total Energy = -2180.4524165383355
# Step = 24500 | Total Energy = -2180.458370000844
# Step = 24600 | Total Energy = -2180.3437967924597
# Step = 24700 | Total Energy = -2180.388043607928
# Step = 24800 | Total Energy = -2180.5399554532555
# Step = 24900 | Total Energy = -2180.3814388630244
# Step = 25000 | Total Energy = -2180.4895964941957
# Step = 25100 | Total Energy = -2180.4511784568276
# Step = 25200 | Total Energy = -2180.26298100825
# Step = 25300 | Total Energy = -2180.4757470844647
# Step = 25400 | Total Energy = -2180.508358334724
# Step = 25500 | Total Energy = -2180.3833641260176
# Step = 25600 | Total Energy = -2180.47281947957
# Step = 25700 | Total Energy = -2180.366651888654
# Step = 25800 | Total Energy = -2180.373777384706
# Step = 25900 | Total Energy = -2180.518297724602
# Step = 26000 | Total Energy = -2180.4811368626
# Step = 26100 | Total Energy = -2180.3680451853998
# Step = 26200 | Total Energy = -2180.436145461853
# Step = 26300 | Total Energy = -2180.265936369475
# Step = 26400 | Total Energy = -2180.350440589013
# Step = 26500 | Total Energy = -2180.3690893683474
# Step = 26600 | Total Energy = -2180.55460616851
# Step = 26700 | Total Energy = -2180.523070210096
# Step = 26800 | Total Energy = -2180.4246365038452
# Step = 26900 | Total Energy = -2180.510156099719
# Step = 27000 | Total Energy = -2180.4176546214126
# Step = 27100 | Total Energy = -2180.4525592673385
# Step = 27200 | Total Energy = -2180.407955306789
# Step = 27300 | Total Energy = -2180.380868458946
# Step = 27400 | Total Energy = -2180.419604651871
# Step = 27500 | Total Energy = -2180.4179319444684
# Step = 27600 | Total Energy = -2180.371418106458
# Step = 27700 | Total Energy = -2180.4742560378363
# Step = 27800 | Total Energy = -2180.395137999189
# Step = 27900 | Total Energy = -2180.4151543612966
# Step = 28000 | Total Energy = -2180.566380915194
# Step = 28100 | Total Energy = -2180.3197419586813
# Step = 28200 | Total Energy = -2180.404945865954
# Step = 28300 | Total Energy = -2180.5011000071054
# Step = 28400 | Total Energy = -2180.4588294321525
# Step = 28500 | Total Energy = -2180.489361181982
# Step = 28600 | Total Energy = -2180.520813928055
# Step = 28700 | Total Energy = -2180.37810830951
# Step = 28800 | Total Energy = -2180.5375486916632
# Step = 28900 | Total Energy = -2180.480959650964
# Step = 29000 | Total Energy = -2180.2806609570525
# Step = 29100 | Total Energy = -2180.4426121890915
# Step = 29200 | Total Energy = -2180.3940580995536
# Step = 29300 | Total Energy = -2180.373610063998
# Step = 29400 | Total Energy = -2180.4030551523997
# Step = 29500 | Total Energy = -2180.453867165815
# Step = 29600 | Total Energy = -2180.4243515983576
# Step = 29700 | Total Energy = -2180.4870659951443
# Step = 29800 | Total Energy = -2180.4712624512063
# Step = 29900 | Total Energy = -2180.442110186234
# Step = 30000 | Total Energy = -2180.4963144037147
# Step = 30100 | Total Energy = -2180.367563369391
# Step = 30200 | Total Energy = -2180.4050418597803
# Step = 30300 | Total Energy = -2180.4962595584793
# Step = 30400 | Total Energy = -2180.375483329762
# Step = 30500 | Total Energy = -2180.470630409133
# Step = 30600 | Total Energy = -2180.414486762017
# Step = 30700 | Total Energy = -2180.3989976054586
# Step = 30800 | Total Energy = -2180.365510989604
# Step = 30900 | Total Energy = -2180.4207992914976
# Step = 31000 | Total Energy = -2180.3846815207553
# Step = 31100 | Total Energy = -2180.4515588669447
# Step = 31200 | Total Energy = -2180.3792181276353
# Step = 31300 | Total Energy = -2180.389481066537
# Step = 31400 | Total Energy = -2180.4454806968565
# Step = 31500 | Total Energy = -2180.445911783181
# Step = 31600 | Total Energy = -2180.4898710729963
# Step = 31700 | Total Energy = -2180.4228872783847
# Step = 31800 | Total Energy = -2180.4567647025806
# Step = 31900 | Total Energy = -2180.394497550508
# Step = 32000 | Total Energy = -2180.341718023451
# Step = 32100 | Total Energy = -2180.529130186855
# Step = 32200 | Total Energy = -2180.453227164909
# Step = 32300 | Total Energy = -2180.425544143551
# Step = 32400 | Total Energy = -2180.3782242643447
# Step = 32500 | Total Energy = -2180.4320138900325
# Step = 32600 | Total Energy = -2180.4104358672153
# Step = 32700 | Total Energy = -2180.551402804605
# Step = 32800 | Total Energy = -2180.279818390003
# Step = 32900 | Total Energy = -2180.4833190035956
# Step = 33000 | Total Energy = -2180.452906969781
# Step = 33100 | Total Energy = -2180.407059517376
# Step = 33200 | Total Energy = -2180.4667439246678
# Step = 33300 | Total Energy = -2180.440592129687
# Step = 33400 | Total Energy = -2180.481304421865
# Step = 33500 | Total Energy = -2180.4829104604646
# Step = 33600 | Total Energy = -2180.4475969900677
# Step = 33700 | Total Energy = -2180.4600337132442
# Step = 33800 | Total Energy = -2180.4730420180435
# Step = 33900 | Total Energy = -2180.392269058199
# Step = 34000 | Total Energy = -2180.3666982037744
# Step = 34100 | Total Energy = -2180.508951106613
# Step = 34200 | Total Energy = -2180.370504762888
# Step = 34300 | Total Energy = -2180.4957405902137
# Step = 34400 | Total Energy = -2180.3822027862248
# Step = 34500 | Total Energy = -2180.4690889172152
# Step = 34600 | Total Energy = -2180.3803951983173
# Step = 34700 | Total Energy = -2180.43885588815
# Step = 34800 | Total Energy = -2180.4196688523816
# Step = 34900 | Total Energy = -2180.4851963836572
# Step = 35000 | Total Energy = -2180.370840633595
# Step = 35100 | Total Energy = -2180.384316659615
# Step = 35200 | Total Energy = -2180.4097385845325
# Step = 35300 | Total Energy = -2180.5338247093778
# Step = 35400 | Total Energy = -2180.404821357216
# Step = 35500 | Total Energy = -2180.4756529646606
# Step = 35600 | Total Energy = -2180.4122182612414
# Step = 35700 | Total Energy = -2180.394242855166
# Step = 35800 | Total Energy = -2180.309981046743
# Step = 35900 | Total Energy = -2180.4814136898576
# Step = 36000 | Total Energy = -2180.437216554126
# Step = 36100 | Total Energy = -2180.4500368781582
# Step = 36200 | Total Energy = -2180.4004807088218
# Step = 36300 | Total Energy = -2180.4099187392076
# Step = 36400 | Total Energy = -2180.376429483483
# Step = 36500 | Total Energy = -2180.481135606588
# Step = 36600 | Total Energy = -2180.329151746214
# Step = 36700 | Total Energy = -2180.4932872175427
# Step = 36800 | Total Energy = -2180.5301745614975
# Step = 36900 | Total Energy = -2180.4290866535785
# Step = 37000 | Total Energy = -2180.447199482218
# Step = 37100 | Total Energy = -2180.481101872493
# Step = 37200 | Total Energy = -2180.3628967688637
# Step = 37300 | Total Energy = -2180.508340774909
# Step = 37400 | Total Energy = -2180.3612018448
# Step = 37500 | Total Energy = -2180.383838763593
# Step = 37600 | Total Energy = -2180.3470137652193
# Step = 37700 | Total Energy = -2180.4191930871875
# Step = 37800 | Total Energy = -2180.379989599815
# Step = 37900 | Total Energy = -2180.5152618901247
# Step = 38000 | Total Energy = -2180.410413161573
# Step = 38100 | Total Energy = -2180.488206742993
# Step = 38200 | Total Energy = -2180.4422884869796
# Step = 38300 | Total Energy = -2180.4567699738695
# Step = 38400 | Total Energy = -2180.436236044042
# Step = 38500 | Total Energy = -2180.4688942738085
# Step = 38600 | Total Energy = -2180.4413516076265
# Step = 38700 | Total Energy = -2180.5071401449077
# Step = 38800 | Total Energy = -2180.3301603784744
# Step = 38900 | Total Energy = -2180.4401518147915
# Step = 39000 | Total Energy = -2180.43850943986
# Step = 39100 | Total Energy = -2180.4242767758337
# Step = 39200 | Total Energy = -2180.407098427698
# Step = 39300 | Total Energy = -2180.364834529852
# Step = 39400 | Total Energy = -2180.395262498168
# Step = 39500 | Total Energy = -2180.471834230635
# Step = 39600 | Total Energy = -2180.357050421476
# Step = 39700 | Total Energy = -2180.5170058085037
# Step = 39800 | Total Energy = -2180.3461529505616
# Step = 39900 | Total Energy = -2180.4697690300404
# Step = 40000 | Total Energy = -2180.3854680593577
# Step = 40100 | Total Energy = -2180.4253245926316
# Step = 40200 | Total Energy = -2180.407043271488
# Step = 40300 | Total Energy = -2180.527485404357
# Step = 40400 | Total Energy = -2180.3828032885644
# Step = 40500 | Total Energy = -2180.4819503137533
# Step = 40600 | Total Energy = -2180.4241364991876
# Step = 40700 | Total Energy = -2180.3033152111284
# Step = 40800 | Total Energy = -2180.444476726799
# Step = 40900 | Total Energy = -2180.4210595952677
# Step = 41000 | Total Energy = -2180.326209284745
# Step = 41100 | Total Energy = -2180.4974622418154
# Step = 41200 | Total Energy = -2180.416739013361
# Step = 41300 | Total Energy = -2180.4042984502903
# Step = 41400 | Total Energy = -2180.41303665712
# Step = 41500 | Total Energy = -2180.4517205671323
# Step = 41600 | Total Energy = -2180.4515605533647
# Step = 41700 | Total Energy = -2180.520953121439
# Step = 41800 | Total Energy = -2180.308628900054
# Step = 41900 | Total Energy = -2180.4532616418687
# Step = 42000 | Total Energy = -2180.46080734362
# Step = 42100 | Total Energy = -2180.4640693299316
# Step = 42200 | Total Energy = -2180.430402595852
# Step = 42300 | Total Energy = -2180.510108154448
# Step = 42400 | Total Energy = -2180.370053795881
# Step = 42500 | Total Energy = -2180.454839011852
# Step = 42600 | Total Energy = -2180.4078380809697
# Step = 42700 | Total Energy = -2180.4241057264444
# Step = 42800 | Total Energy = -2180.4491301659464
# Step = 42900 | Total Energy = -2180.453179176858
# Step = 43000 | Total Energy = -2180.363517596523
# Step = 43100 | Total Energy = -2180.4627107914957
# Step = 43200 | Total Energy = -2180.3594427270855
# Step = 43300 | Total Energy = -2180.458116528047
# Step = 43400 | Total Energy = -2180.403226512042
# Step = 43500 | Total Energy = -2180.48382175229
# Step = 43600 | Total Energy = -2180.4760840275803
# Step = 43700 | Total Energy = -2180.4322775635114
# Step = 43800 | Total Energy = -2180.4452267734705
# Step = 43900 | Total Energy = -2180.409669978167
# Step = 44000 | Total Energy = -2180.322318153805
# Step = 44100 | Total Energy = -2180.3988155136462
# Step = 44200 | Total Energy = -2180.430651662043
# Step = 44300 | Total Energy = -2180.4095377642366
# Step = 44400 | Total Energy = -2180.42413287406
# Step = 44500 | Total Energy = -2180.4222454213173
# Step = 44600 | Total Energy = -2180.387107883568
# Step = 44700 | Total Energy = -2180.4932603820193
# Step = 44800 | Total Energy = -2180.3894767660086
# Step = 44900 | Total Energy = -2180.4286616109134
# Step = 45000 | Total Energy = -2180.3665278596854
# Step = 45100 | Total Energy = -2180.38160032423
# Step = 45200 | Total Energy = -2180.3873303691757
# Step = 45300 | Total Energy = -2180.5153268278227
# Step = 45400 | Total Energy = -2180.4988073764366
# Step = 45500 | Total Energy = -2180.4905450877554
# Step = 45600 | Total Energy = -2180.305983856419
# Step = 45700 | Total Energy = -2180.4174163263397
# Step = 45800 | Total Energy = -2180.4656611501014
# Step = 45900 | Total Energy = -2180.373248673684
# Step = 46000 | Total Energy = -2180.460067919473
# Step = 46100 | Total Energy = -2180.4177629257733
# Step = 46200 | Total Energy = -2180.411288289476
# Step = 46300 | Total Energy = -2180.4163362850823
# Step = 46400 | Total Energy = -2180.450559854649
# Step = 46500 | Total Energy = -2180.44702012393
# Step = 46600 | Total Energy = -2180.4670197569676
# Step = 46700 | Total Energy = -2180.3917729871264
# Step = 46800 | Total Energy = -2180.404549961386
# Step = 46900 | Total Energy = -2180.4193059394674
# Step = 47000 | Total Energy = -2180.3971766662185
# Step = 47100 | Total Energy = -2180.5058220760566
# Step = 47200 | Total Energy = -2180.4112733457305
# Step = 47300 | Total Energy = -2180.4416645463143
# Step = 47400 | Total Energy = -2180.3832091792724
# Step = 47500 | Total Energy = -2180.4420355849575
# Step = 47600 | Total Energy = -2180.447671675251
# Step = 47700 | Total Energy = -2180.4467370384828
# Step = 47800 | Total Energy = -2180.35780455361
# Step = 47900 | Total Energy = -2180.437206405394
# Step = 48000 | Total Energy = -2180.5050020677268
# Step = 48100 | Total Energy = -2180.35217851112
# Step = 48200 | Total Energy = -2180.381856124952
# Step = 48300 | Total Energy = -2180.395821850362
# Step = 48400 | Total Energy = -2180.4326895414606
# Step = 48500 | Total Energy = -2180.4515500909583
# Step = 48600 | Total Energy = -2180.416715566114
# Step = 48700 | Total Energy = -2180.3977600660737
# Step = 48800 | Total Energy = -2180.469785484114
# Step = 48900 | Total Energy = -2180.4058995788523
# Step = 49000 | Total Energy = -2180.381700413939
# Step = 49100 | Total Energy = -2180.4554778022157
# Step = 49200 | Total Energy = -2180.3784837913877
# Step = 49300 | Total Energy = -2180.409189725469
# Step = 49400 | Total Energy = -2180.4309857608764
# Step = 49500 | Total Energy = -2180.451405300251
# Step = 49600 | Total Energy = -2180.454021944603
# Step = 49700 | Total Energy = -2180.4153127037284
# Step = 49800 | Total Energy = -2180.4255102751276
# Step = 49900 | Total Energy = -2180.4475690121003

# %%
# Check if neighbors overflowed
print(nbrs_r.did_buffer_overflow)
# Out:
# 0

# %%
Nsteps = int(steps/write_every)
t = jnp.arange(0, Nsteps,dtype=f64) * timestep * write_every

# %%
plt.style.use('seaborn-dark-palette')
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams.update({'font.size': 12})
fig = plt.figure(figsize=(16, 8))

ax1 = plt.subplot(2, 2, 1)
ax1.plot(t, log_r['kT'] / unit['temperature'], lw=4, label='JAX MD')
ax1.plot(t_l, T_l, lw=2, label='LAMMPS')
ax1.set_title('Temperature', fontsize=16)
ax1.set_ylabel("$T\ (K)$", fontsize=16)
ax1.set_xlabel("$t\ (ps)$", fontsize=16)
ax1.legend()

ax2 = plt.subplot(2, 2, 2)
ax2.plot(t, (log_r['P'] / unit['pressure']) / 10000, lw=4, label='JAX MD')
ax2.plot(t_l, P_l/10000, lw=2, label='LAMMPS')
ax2.set_title('Pressure', fontsize=16)
ax2.set_ylabel("$P\ (GPa)$", fontsize=16)
ax2.set_xlabel("$t\ (ps)$", fontsize=16)
ax2.legend()

ax3 = plt.subplot(2, 2, 3)
ax3.plot(t, log_r['E'], lw=4, label='JAX MD')
ax3.plot(t_l, E_l, lw=2, label='LAMMPS')
ax3.set_title('Potential Energy', fontsize=16)
ax3.set_ylabel("$E_{PE}\ (eV)$", fontsize=16)
ax3.set_xlabel("$t\ (ps)$", fontsize=16)
ax3.legend()

fig.tight_layout()
# Out:
# <ipython-input-11-65aea012eda0>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark-palette')
